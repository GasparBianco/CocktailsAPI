# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'D:\Programacion\CoctailsAPI\all_drinks.csv', delimiter = ",")

# %%
df.head()
# Out:
#    Unnamed: 0                              strDrink         dateModified  \
# 0           0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1           1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2           2                      110 in the shade  2016-02-03 14:51:57
# 3           3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4           4                           155 Belmont  2016-10-05 12:36:28
#
#    idDrink strAlcoholic           strCategory  \
# 0    14029    Alcoholic              Cocktail
# 1    15395    Alcoholic                  Shot
# 2    15423    Alcoholic                  Beer
# 3    14588    Alcoholic  Milk / Float / Shake
# 4    15346    Alcoholic              Cocktail
#
#                                        strDrinkThumb             strGlass  \
# 0  http://www.thecocktaildb.com/images/media/drin...       Highball glass
# 1  http://www.thecocktaildb.com/images/media/drin...  Old-fashioned glass
# ...

# %%
df = df.drop(["strVideo","Unnamed: 0","dateModified","idDrink","strDrinkThumb","strIBA"], axis=1)

# %%
df.insert(3,"Ingredients","-")
df
# Out:
#                                  strDrink strAlcoholic           strCategory  \
# 0    '57 Chevy with a White License Plate    Alcoholic              Cocktail
# 1                          1-900-FUK-MEUP    Alcoholic                  Shot
# 2                        110 in the shade    Alcoholic                  Beer
# 3                  151 Florida Bushwacker    Alcoholic  Milk / Float / Shake
# 4                             155 Belmont    Alcoholic              Cocktail
# ..                                    ...          ...                   ...
# 541                       Zippy's Revenge    Alcoholic              Cocktail
# 542                        Zizi Coin-coin    Alcoholic   Punch / Party Drink
# 543                                Zoksel    Alcoholic     Soft Drink / Soda
# 544                             Zorbatini    Alcoholic              Cocktail
# 545                                 Zorro    Alcoholic          Coffee / Tea
#
# ...

# %%
df.insert(4,"Measure","-")
df
# Out:
#                                  strDrink strAlcoholic           strCategory  \
# 0    '57 Chevy with a White License Plate    Alcoholic              Cocktail
# 1                          1-900-FUK-MEUP    Alcoholic                  Shot
# 2                        110 in the shade    Alcoholic                  Beer
# 3                  151 Florida Bushwacker    Alcoholic  Milk / Float / Shake
# 4                             155 Belmont    Alcoholic              Cocktail
# ..                                    ...          ...                   ...
# 541                       Zippy's Revenge    Alcoholic              Cocktail
# 542                        Zizi Coin-coin    Alcoholic   Punch / Party Drink
# 543                                Zoksel    Alcoholic     Soft Drink / Soda
# 544                             Zorbatini    Alcoholic              Cocktail
# 545                                 Zorro    Alcoholic          Coffee / Tea
#
# ...

# %%
for i in np.arange(546):
    
    array = []
    j=1
    
    while j <=15:        
            
        temp="strIngredient"+str(j)
        j=j+1
            
        if type(df[temp][i]) == str: 
                
            array.append(df[temp][i])
        
        else:
            df["Ingredients"][i]=array
            j=16
# Out:
# C:\Users\Gaspar\AppData\Local\Temp\ipykernel_4036\3569120808.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ingredients"][i]=array

# %%
df["Ingredients"]
# Out:
# 0                                [Creme de Cacao, Vodka]
# 1      [Absolut Kurant, Grand Marnier, Chambord raspb...
# 2                                       [Lager, Tequila]
# 3      [Malibu rum, Light rum, 151 proof rum, Dark Cr...
# 4             [Dark rum, Light rum, Vodka, Orange juice]
#                              ...
# 541                            [Amaretto, Rum, Kool-Aid]
# 542                 [Cointreau, Lemon juice, Ice, Lemon]
# 543    [Beer, Root beer, Lemonade, Coca-Cola, 7-Up, C...
# 544                                        [Vodka, Ouzo]
# 545    [Sambuca, Bailey's irish cream, White Creme de...
# Name: Ingredients, Length: 546, dtype: object

# %%
for i in np.arange(546):
    
    array = []
    j=1
    
    while j <=15:        
        
        temp_0 = "strIngredient"+str(j)
        temp="strMeasure"+str(j)
        j=j+1
            
        if type(df[temp_0][i]) == str: 
                
            array.append(df[temp][i])
        
        else:
            df["Measure"][i]=array
            j=16
# Out:
# C:\Users\Gaspar\AppData\Local\Temp\ipykernel_4036\4235631187.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Measure"][i]=array

# %%
df.columns
# Out:
# Index(['strDrink', 'strAlcoholic', 'strCategory', 'Ingredients', 'Measure',
#        'strGlass', 'strIngredient1', 'strIngredient10', 'strIngredient11',
#        'strIngredient12', 'strIngredient13', 'strIngredient14',
#        'strIngredient15', 'strIngredient2', 'strIngredient3', 'strIngredient4',
#        'strIngredient5', 'strIngredient6', 'strIngredient7', 'strIngredient8',
#        'strIngredient9', 'strInstructions', 'strMeasure1', 'strMeasure10',
#        'strMeasure11', 'strMeasure12', 'strMeasure13', 'strMeasure14',
#        'strMeasure15', 'strMeasure2', 'strMeasure3', 'strMeasure4',
#        'strMeasure5', 'strMeasure6', 'strMeasure7', 'strMeasure8',
#        'strMeasure9'],
#       dtype='object')

# %%
count=0
array=[]

for i in np.arange(546):
    if "\n" in df["Measure"][i]:
        count=count+1
        array.append(i)

# %%
df = df.drop(array,axis=0)

# %%
df
# Out:
#                                  strDrink strAlcoholic           strCategory  \
# 0    '57 Chevy with a White License Plate    Alcoholic              Cocktail
# 1                          1-900-FUK-MEUP    Alcoholic                  Shot
# 2                        110 in the shade    Alcoholic                  Beer
# 3                  151 Florida Bushwacker    Alcoholic  Milk / Float / Shake
# 4                             155 Belmont    Alcoholic              Cocktail
# ..                                    ...          ...                   ...
# 540                            Zipperhead    Alcoholic                  Shot
# 541                       Zippy's Revenge    Alcoholic              Cocktail
# 542                        Zizi Coin-coin    Alcoholic   Punch / Party Drink
# 544                             Zorbatini    Alcoholic              Cocktail
# 545                                 Zorro    Alcoholic          Coffee / Tea
#
# ...

# %%
i=1
while i <= 15:
    temp="strIngredient"+str(i)
    df = df.drop(temp,axis=1)
    temp="strMeasure"+str(i)
    df = df.drop(temp,axis=1)
    i=i+1
df.head()
# Out:
#                                strDrink strAlcoholic           strCategory  \
# 0  '57 Chevy with a White License Plate    Alcoholic              Cocktail
# 1                        1-900-FUK-MEUP    Alcoholic                  Shot
# 2                      110 in the shade    Alcoholic                  Beer
# 3                151 Florida Bushwacker    Alcoholic  Milk / Float / Shake
# 4                           155 Belmont    Alcoholic              Cocktail
#
#                                          Ingredients  \
# 0                            [Creme de Cacao, Vodka]
# 1  [Absolut Kurant, Grand Marnier, Chambord raspb...
# 2                                   [Lager, Tequila]
# 3  [Malibu rum, Light rum, 151 proof rum, Dark Cr...
# 4         [Dark rum, Light rum, Vodka, Orange juice]
#
#                                              Measure             strGlass  \
# 0                               [1 oz white , 1 oz ]       Highball glass
# ...

# %%
df = df.drop(["strAlcoholic","strCategory","strGlass"],axis=1)
df
# Out:
#                                  strDrink  \
# 0    '57 Chevy with a White License Plate
# 1                          1-900-FUK-MEUP
# 2                        110 in the shade
# 3                  151 Florida Bushwacker
# 4                             155 Belmont
# ..                                    ...
# 540                            Zipperhead
# 541                       Zippy's Revenge
# 542                        Zizi Coin-coin
# 544                             Zorbatini
# 545                                 Zorro
#
#                                            Ingredients  \
# 0                              [Creme de Cacao, Vodka]
# 1    [Absolut Kurant, Grand Marnier, Chambord raspb...
# 2                                     [Lager, Tequila]
# 3    [Malibu rum, Light rum, 151 proof rum, Dark Cr...
# 4           [Dark rum, Light rum, Vodka, Orange juice]
# ..                                                 ...
# 540    [Chambord raspberry liqueur, Vodka, Soda water]
# ...

# %%
df.to_csv("cocktails_db.csv", index=False)
